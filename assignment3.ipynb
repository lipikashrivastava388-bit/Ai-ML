# %% [markdown]
# ## Q.1 Perform K-Means on Iris dataset and visualize clusters.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = load_iris()
df  = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x = df.values

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(x)
# Out:
# C:\Users\lipik\OneDrive\Documents\New folder\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
labels = kmeans.labels_

# %%
centroids = kmeans.cluster_centers_

# %%
plt.figure()

# %%
plt.scatter(x[:,0], x[:,1], c=labels)
plt.scatter(centroids[:,0], centroids[:,1], marker='x', s=200)

# %%
plt.figure()
plt.scatter(x[:,0], x[:,1], c=labels)

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('K-Means Clustering on Iris Dataset')

plt.show()

# %% [markdown]
# ## Q.2 Apply PCA to reduce dataset dimensions.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

# %%
print('Explained Variance Ratio:')
print(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio:
# [0.72962445 0.22850762]

# %%
plt.figure()
plt.scatter(x_pca[:,0], x_pca[:,1])

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on Iris Dataset')

plt.show()
